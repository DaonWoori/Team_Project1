# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/team_project1/
# Out:
# /content/drive/MyDrive/team_project1

# %%
# 회귀 모델 동작 -> 단층 퍼셉트론

# 회귀문제 단층 퍼셉트론 모델 불러오기 
# %run ./AnnModel1.ipynb

# 메서드 동작
main()
# Out:
# AnnModel1의 main 실행
# AnnModel1의 load_data 실행
# AnnModel1의 init_param 실행
# AnnModel1의 train_and_test
# AnnModel1의 arrange_data 실행
# Epoch 1   : Train - Loss = 11.416, Accuracy = 0.776 / Test - Accuracy = 0.804
# Epoch 2   : Train - Loss = 7.116, Accuracy = 0.806 / Test - Accuracy = 0.802
# Epoch 3   : Train - Loss = 6.980, Accuracy = 0.807 / Test - Accuracy = 0.810
# Epoch 4   : Train - Loss = 6.889, Accuracy = 0.808 / Test - Accuracy = 0.809
# Epoch 5   : Train - Loss = 6.805, Accuracy = 0.809 / Test - Accuracy = 0.803
# Epoch 6   : Train - Loss = 6.715, Accuracy = 0.811 / Test - Accuracy = 0.798
# Epoch 7   : Train - Loss = 6.630, Accuracy = 0.811 / Test - Accuracy = 0.815
# Epoch 8   : Train - Loss = 6.550, Accuracy = 0.813 / Test - Accuracy = 0.807
# Epoch 9   : Train - Loss = 6.478, Accuracy = 0.814 / Test - Accuracy = 0.808
# Epoch 10   : Train - Loss = 6.403, Accuracy = 0.815 / Test - Accuracy = 0.813
# ==============================  Final TEST  ==============================
#
# Final Accuracy = 0.813

# %%
# 회귀 모델 동작 -> 다층 퍼셉트론

# 회귀문제 단층 퍼셉트론 모델 불러오기 
# %run ./mlp.ipynb
# %run ./AnnModel1.ipynb
# 다층 퍼셉트론 기능 추가 
# %run ./mlp.ipynb

# 아무 값도 입력하지 않으면 은닉계층을 갖지 않는 SLP 이 구축됩니다.
set_hidden([1,2])
# 메서드 동작
main()
# Out:
# mlp의 set_hidden 실행
# AnnModel1의 main 실행
# AnnModel1의 load_data 실행
# mlp의 init_param 실행
# [안내] 은닉 계층 2개를 갖는 다층 퍼셉트론이 적용됩니다.
# mlp의 init_param_hiddens 실행
# mlp의 allocate_param_pair 실행
# mlp의 allocate_param_pair 실행
# mlp의 allocate_param_pair 실행
# AnnModel1의 train_and_test
# AnnModel1의 arrange_data 실행
# Epoch 1   : Train - Loss = 9.439, Accuracy = 0.779 / Test - Accuracy = 0.802
# Epoch 2   : Train - Loss = 7.057, Accuracy = 0.803 / Test - Accuracy = 0.731
# Epoch 3   : Train - Loss = 6.900, Accuracy = 0.804 / Test - Accuracy = 0.703
# Epoch 4   : Train - Loss = 6.473, Accuracy = 0.810 / Test - Accuracy = 0.842
# Epoch 5   : Train - Loss = 6.257, Accuracy = 0.814 / Test - Accuracy = 0.821
# Epoch 6   : Train - Loss = 6.052, Accuracy = 0.816 / Test - Accuracy = 0.843
# Epoch 7   : Train - Loss = 5.964, Accuracy = 0.820 / Test - Accuracy = 0.827
# Epoch 8   : Train - Loss = 5.774, Accuracy = 0.820 / Test - Accuracy = 0.810
# Epoch 9   : Train - Loss = 5.814, Accuracy = 0.820 / Test - Accuracy = 0.840
# Epoch 10   : Train - Loss = 5.904, Accuracy = 0.819 / Test - Accuracy = 0.802
# ==============================  Final TEST  ==============================
#
# Final Accuracy = 0.802

# %%
# 이진판단 모델동작

# 회귀문제 단층 퍼셉트론 모델 불러오기 
# %run ./AnnModel2.ipynb
# 다층 퍼셉트론 기능 추가 
# %run ./mlp.ipynb

# 아무 값도 입력하지 않으면 은닉계층을 갖지 않는 SLP 이 구축됩니다.
set_hidden([1,2])
# 메서드 동작
binary_main()
# Out:
# mlp의 set_hidden 실행
# mlp의 init_param 실행
# [안내] 은닉 계층 2개를 갖는 다층 퍼셉트론이 적용됩니다.
# mlp의 init_param_hiddens 실행
# mlp의 allocate_param_pair 실행
# mlp의 allocate_param_pair 실행
# mlp의 allocate_param_pair 실행
# AnnModel1의 train_and_test
# AnnModel1의 arrange_data 실행
# Epoch 1   : Train - Loss = 0.407, Accuracy = 0.909 / Test - Accuracy = 0.909
# Epoch 2   : Train - Loss = 0.301, Accuracy = 0.916 / Test - Accuracy = 0.923
# Epoch 3   : Train - Loss = 0.229, Accuracy = 0.943 / Test - Accuracy = 0.955
# Epoch 4   : Train - Loss = 0.154, Accuracy = 0.963 / Test - Accuracy = 0.968
# Epoch 5   : Train - Loss = 0.125, Accuracy = 0.968 / Test - Accuracy = 0.970
# Epoch 6   : Train - Loss = 0.115, Accuracy = 0.969 / Test - Accuracy = 0.969
# Epoch 7   : Train - Loss = 0.111, Accuracy = 0.970 / Test - Accuracy = 0.972
# Epoch 8   : Train - Loss = 0.109, Accuracy = 0.970 / Test - Accuracy = 0.967
# Epoch 9   : Train - Loss = 0.106, Accuracy = 0.970 / Test - Accuracy = 0.972
# Epoch 10   : Train - Loss = 0.107, Accuracy = 0.970 / Test - Accuracy = 0.970
# ==============================  Final TEST  ==============================
#
# Final Accuracy = 0.970

# %%
# 이진판단 모델동작, 평가지표 개선 및 데이터 증폭 작업 실시

# 회귀문제 단층 퍼셉트론 모델 불러오기 
# %run ./AnnModel2_Plus.ipynb
# 다층 퍼셉트론 기능 추가 
# %run ./mlp.ipynb

# 아무 값도 입력하지 않으면 은닉계층을 갖지 않는 SLP 이 구축됩니다.
set_hidden([1,2])
# 메서드 동작
binary_main(adjust_ratio = True)
# Out:
# [안내] 은닉 계층 2개를 갖는 다층 퍼셉트론이 적용됩니다.
# [Epoch 1] Train Loss = 0.693 | Test Acc = 0.501, Precision = 0.000, Recall = 0.000, F1 = 0.000
# [Epoch 2] Train Loss = 0.693 | Test Acc = 0.501, Precision = 0.000, Recall = 0.000, F1 = 0.000
# [Epoch 3] Train Loss = 0.693 | Test Acc = 0.499, Precision = 0.499, Recall = 1.000, F1 = 0.666
# [Epoch 4] Train Loss = 0.693 | Test Acc = 0.501, Precision = 0.000, Recall = 0.000, F1 = 0.000
# [Epoch 5] Train Loss = 0.693 | Test Acc = 0.501, Precision = 0.000, Recall = 0.000, F1 = 0.000
# [Epoch 6] Train Loss = 0.693 | Test Acc = 0.499, Precision = 0.499, Recall = 1.000, F1 = 0.666
# [Epoch 7] Train Loss = 0.693 | Test Acc = 0.501, Precision = 0.000, Recall = 0.000, F1 = 0.000
# [Epoch 8] Train Loss = 0.693 | Test Acc = 0.499, Precision = 0.499, Recall = 1.000, F1 = 0.666
# [Epoch 9] Train Loss = 0.693 | Test Acc = 0.501, Precision = 0.000, Recall = 0.000, F1 = 0.000
# [Epoch 10] Train Loss = 0.693 | Test Acc = 0.501, Precision = 0.000, Recall = 0.000, F1 = 0.000
#
#  ========================================  FINAL TEST REPORT ========================================
#
# ► Acc = 0.501 Precision = 0.000, Recall = 0.000, F1 = 0.000

# %%
# 회귀문제 단층 퍼셉트론 모델 불러오기 
# %run ./AnnModel3.ipynb
# 다층 퍼셉트론 기능 추가 
# %run ./mlp.ipynb

# 아무 값도 입력하지 않으면 은닉계층을 갖지 않는 SLP 이 구축됩니다.
set_hidden([2,5])
# 메서드 동작
multiple_main()
# Out:
# [안내] 은닉 계층 2개를 갖는 다층 퍼셉트론이 적용됩니다.
# Epoch 1   : Train - Loss = 2.249, Accuracy = 0.338 / Test - Accuracy = 0.353
# Epoch 2   : Train - Loss = 1.843, Accuracy = 0.342 / Test - Accuracy = 0.353
# Epoch 3   : Train - Loss = 1.800, Accuracy = 0.342 / Test - Accuracy = 0.353
# Epoch 4   : Train - Loss = 1.770, Accuracy = 0.342 / Test - Accuracy = 0.353
# Epoch 5   : Train - Loss = 1.749, Accuracy = 0.342 / Test - Accuracy = 0.353
# Epoch 6   : Train - Loss = 1.734, Accuracy = 0.342 / Test - Accuracy = 0.353
# Epoch 7   : Train - Loss = 1.723, Accuracy = 0.342 / Test - Accuracy = 0.353
# Epoch 8   : Train - Loss = 1.715, Accuracy = 0.342 / Test - Accuracy = 0.353
# Epoch 9   : Train - Loss = 1.709, Accuracy = 0.342 / Test - Accuracy = 0.353
# Epoch 10   : Train - Loss = 1.705, Accuracy = 0.342 / Test - Accuracy = 0.353
# ==============================  Final TEST  ==============================
#
# Final Accuracy = 0.353
