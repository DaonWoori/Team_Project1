# %% [markdown]
# ### 1.데이터 전처리

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### 1-1. 데이터 불러오기

# %%
path = "/content/drive/MyDrive/team_project1/data/"

# %%
df = pd.read_csv(path + 'Regression_data.csv')
print(df.shape)
df.head()
# Out:
# (4177, 9)
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %% [markdown]
# #### 1-2. Height 이상치 및 결측치 처리

# %%
# 이상치 -> 0.5 이상
# length나 diameter가 동일한 값을 가진 데이터들의 평균값을 활용
df[df['Height'] > 0.5]
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 1417   M   0.705     0.565   0.515         2.210          1.1075
# 2051   F   0.455     0.355   1.130         0.594          0.3320
#
#       Viscera weight  Shell weight  Rings
# 1417          0.4865        0.5120     10
# 2051          0.1160        0.1335      8

# %%
df.loc[1417, 'Height'] = df[df['Diameter'] == 0.455]['Height'].mean().round(4)
df.loc[1417, 'Height']
# Out:
# 0.1552

# %%
df.loc[2051, 'Height'] = df[df['Diameter'] == 0.355]['Height'].mean().round(4)
df.loc[2051, 'Height']
# Out:
# 0.1368

# %%
# 결측치 처리 -> 값이 0
# # length나 diameter가 동일한 값을 가진 데이터들의 평균값을 활용
df[df['Height'] == 0]
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 1257   I   0.430      0.34     0.0         0.428          0.2065
# 3996   I   0.315      0.23     0.0         0.134          0.0575
#
#       Viscera weight  Shell weight  Rings
# 1257          0.0860        0.1150      8
# 3996          0.0285        0.3505      6

# %%
df.loc[1257, 'Height'] = df[df['Diameter'] == 0.34]['Height'].mean().round(4)
df.loc[3996, 'Height'] = df[df['Diameter'] == 0.23]['Height'].mean().round(4)

# %%
df[df['Height'] == 0]
# Out:
# Empty DataFrame
# Columns: [Sex, Length, Diameter, Height, Whole weight, Shucked weight, Viscera weight, Shell weight, Rings]
# Index: []

# %%
# 파일 저장
# df.to_csv(path + "Regression_data_preprocessing.csv", index=False)

# %% [markdown]
# #### 1-3. 인코딩
# - onehot_encoding vs label_encoding
# - label_encoding의 경우 피쳐들 간의 관계성이 생겨서 잘못 인식하여 값에 왜곡이 생길 수 있어 선형회귀와 같은 알고리즘에는 보통 적용x [출처](https://hye-z.tistory.com/m/16)

# %%
# onehot encoding
df_onehot = pd.get_dummies(df)
df_onehot.shape
# Out:
# (4177, 11)

# %%
# 파일 저장
df_onehot.to_csv(path + "Regression_data_onehot.csv", index=False)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
df_original = df.copy()

# %%
# Label encoder
le = LabelEncoder()
le.fit(df_original['Sex'])
df_original['Sex'] = le.transform(df['Sex'])

df_original.head()
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    2   0.455     0.365   0.095        0.5140          0.2245
# 1    2   0.350     0.265   0.090        0.2255          0.0995
# 2    0   0.530     0.420   0.135        0.6770          0.2565
# 3    2   0.440     0.365   0.125        0.5160          0.2155
# 4    1   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera weight  Shell weight  Rings
# 0          0.1010         0.150     15
# 1          0.0485         0.070      7
# 2          0.1415         0.210      9
# 3          0.1140         0.155     10
# 4          0.0395         0.055      7

# %%
# 파일 저장
df_original.to_csv(path + "Regression_data_label.csv", index=False)
